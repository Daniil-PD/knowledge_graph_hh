# %%
import pickle
import networkx as nx
import matplotlib.pyplot as plt

# %%
with open('graphs_pkl\\graph_2016.pkl', 'rb') as f:
    graph_obj = pickle.load(f)

# %%
plt.plot(nx.degree_histogram(graph_obj), scaley="4")
